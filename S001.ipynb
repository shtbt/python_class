# %% [markdown]
# ---
#
#
# Session Number: 1
#
# Level: Core
#
# Runtime: 60 min
#
# Subjects:
# *   Introductions
# *   Python Syntax
# *   Simple Operations
# *   String Basics
#
# ---

# %% [markdown]
# **Introductions**
#
# > - What is Python?
#
# > - History of Python:
#
# > >>https://en.wikipedia.org/wiki/Python_(programming_language)
#
# > >>https://en.wikipedia.org/wiki/History_of_Python
#
# > >>https://en.wikipedia.org/wiki/Guido_van_Rossum
#
# > >>https://en.wikipedia.org/wiki/Zen_of_Python
#
# > - What can Python do?
# > > https://www.w3schools.com/python/python_intro.asp
#
# > - Why Python?
# >> https://www.w3schools.com/python/python_intro.asp
#
# > - Python Syntax compared to other programming languages
# >>https://www.w3schools.com/python/python_intro.asp
#
# ---

# %% [markdown]
# **Introduction to Google Colab**
#
#
# > https://colab.research.google.com/
#
# > https://drive.google.com/drive/folders/1wRNmggmxIqDAplk0pQ0MTIXaFDKR3ITO?usp=sharing
#
# ---

# %% [markdown]
# **Python Syntax**
#
# >• Execute Python Syntax
#
# >• Python Indentation
#
# >• Python Variables (Creating, Casting, Types, Get the Type )
#
# >• Comments
#
# https://www.w3schools.com/python/python_syntax.asp

# %% [markdown]
# # Introduction to colab
# >https://colab.research.google.com/

# %% [markdown]
# #Python Syntax

# %%
#Execute Python Syntax
#Write a hello world python program
print('hello world')

# %%
#Identation example

if 5 > 2:
 print("Five is greater than two!") 
if 5 > 2:
        print("Five is greater than two!")

# %%
#Comment
#This is a comment
# https://www.w3schools.com/python/python_comments.asp
print("Hello, World!")


print("Hello, World!") #This is a comment

#print("Hello, World!")
print("Cheers, Mate!")


#Multi Line Comments
#This is a comment
#written in
#more than just one line
print("Hello, World!")


"""
This is a comment
written in
more than just one line
"""

#print("Hello, World!")

# %% [markdown]
# # Variables in Python

# %%
#Variables in Python:
#https://www.w3schools.com/python/python_variables.asp

x = 5
y = "Hello, World!"
z=None
a=True
b=2
type(b)
# Out:
# int

# %%
#Variables do not need to be declared with any particular type, and can even change type after they have been set.
x = 4       # x is of type int
x = "Sally" # x is now of type str
print(x)

# %%
#Get the Type
x = 5
y = "John"
print(type(x))
print(type(y))

# %%
#Casting
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float('3')  # z will be 3.0
print(z)

# %%
# Single or Double Quotes?
# String variables can be declared either by using single or double quotes:
x = "John"
# is the same as
x = 'John'

# %%
#Case-Sensitive
a = 4
A = "Sally"
#A will not overwrite a

# %%
# Variable Names
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume). Rules for Python variables:
# A variable name must start with a letter or the underscore character
# A variable name cannot start with a number
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# Variable names are case-sensitive (age, Age and AGE are three different variables)

# Legal variable names:

myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

# %%
# Illegal variable names:

2myvar = "John"
my-var = "John"
my var = "John"

# %%
# One Value to Multiple Variables
x = y = z = "Orange"
print(x)
print(y)
print(z)

# %%
# Unpack a Collection
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)

# %% [markdown]
# #print Function

# %%
x = "Python is awesome"
print(x)
#In the print() function, you output multiple variables, separated by a comma:
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)

# %%
#You can also use the + operator to output multiple variables:
x = "Python "
y = "is "
z = "awesome"
print(x + y + z)
# Out:
# Python is awesome

# %%
#For numbers, the + character works as a mathematical operator:
x = 5
y = 10
print(x + y)

# %%
#In the print() function, when you try to combine a string and a number with the + operator, Python will give you an error:
x = 5
y = "John"
print(x + y)

# %%
# The best way to output multiple variables in the print() function is to separate them with commas, which even support different data types:
x = 5
y = "John"
print(x, y)

# %% [markdown]
# #Python String
# > https://www.w3schools.com/python/python_strings.asp

# %%
#Python Strings

print("Hello")
print('Hello')

s='hello'
print(s)

# %%
#Multiline Strings

a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)

a = '''Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua.'''

print(a)

# %%
#Strings are Arrays

# Like many other popular programming languages, strings in Python are arrays of bytes representing unicode characters.
# However, Python does not have a character data type, a single character is simply a string with a length of 1.
# Square brackets can be used to access elements of the string.
a = "Hello, World!"
print(a[1])

for x in "banana":
  print(x)

# %%
#len function
a = "Hello, World!"
print(len(a))

# %%
#String Functions: upper
a = "Hello, World!"
print(a.upper())

# %%
#String Functions: lower
a = "Hello, World!"
print(a.lower())

# %%
#String Functions: strip
a = " Hello, World! "
print(a.strip()) # returns "Hello, World!"

# %%
#String Functions: replace
a = "Hello, World!"
print(a.replace("H", "J"))

# %%
#String Functions: split
a = "Hello, World!"
print(a.split(",")) # returns ['Hello', ' World!']

# %%
# String Concatenation

a = "Hello"
b = "World"
c = a + b
print(c)

a = "Hello"
b = "World"
c = a + " " + b
print(c)

# %%
#String Slicing (A point to indexes)
b = "Hello, World!"
print(b[2:5])

b = "Hello, World!"
print(b[:5])

# %%
### More on String
# https://www.w3schools.com/python/python_ref_string.asp

# %% [markdown]
# # **Homework #1:**
# > Install Python 3.8 on your system from https://www.python.org
#
# > Download Address:
#
# >> - Download Windows installer (32-bit): https://www.python.org/ftp/python/3.8.10/python-3.8.10.exe
#
# >> - Download Windows installer (64-bit): https://www.python.org/ftp/python/3.8.10/python-3.8.10-amd64.exe
#
# >> - Download macOS 64-bit Intel installer: https://www.python.org/ftp/python/3.8.10/python-3.8.10-macosx10.9.pkg
#
# >> - Download macOS 64-bit universal2 installer: https://www.python.org/ftp/python/3.8.10/python-3.8.10-macos11.pkg
#
# >> - Linux: Instructions Example: https://www.linuxcapable.com/how-to-install-python-3-8-on-ubuntu-22-04-lts/

# %% [markdown]
# **Zen of Python**
#
# >https://en.wikipedia.org/wiki/Zen_of_Python

# %%
# Show Zen of Python 
import this

# %% [markdown]
# More to Read:
# >https://www.monterail.com/blog/is-python-slow
